# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
superstore_df = pd.read_csv("1 - Sample - Superstore.csv", encoding="ANSI")

# %%
superstore_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
superstore_df.tail(2)
# Out:
#       Row ID        Order ID Order Date Ship Date       Ship Mode Customer ID  \
# 9992    9993  CA-2017-121258  2/26/2017  3/3/2017  Standard Class    DB-13060
# 9993    9994  CA-2017-119914   5/4/2017  5/9/2017    Second Class    CC-12220
#
#      Customer Name   Segment        Country         City  ... Postal Code  \
# 9992   Dave Brooks  Consumer  United States   Costa Mesa  ...       92627
# 9993  Chris Cortes  Consumer  United States  Westminster  ...       92683
#
#       Region       Product ID         Category Sub-Category  \
# 9992    West  OFF-PA-10004041  Office Supplies        Paper
# 9993    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16         2
#
#       Discount  Profit
# 9992       0.0  13.320
# 9993       0.0  72.948
#
# ...

# %%
superstore_df.shape
# Out:
# (9994, 21)

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
superstore_df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
superstore_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
superstore_df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
import pandas as pd

superstore_df = pd.read_csv("1 - Sample - Superstore.csv")

superstore_df.head()
superstore_df.tail(2)
superstore_df.shape
superstore_df.info()
superstore_df.describe()
superstore_df.columns
superstore_df.index
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[18], line 3
#       1 import pandas as pd
# ----> 3 superstore_df = pd.read_csv("1 - Sample - Superstore.csv")
#       5 superstore_df.head()
#       6 superstore_df.tail(2)
#
# ...

# %%
students_data = {
    'Name' : ["Adeen", "Rimsha", "Ahmed"],
    "Age" : [21, 23, 24],
    "Score": [75, 85, 65]
}

students_df = pd.DataFrame(students_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       1 students_data = {
#       2     'Name' : ["Adeen", "Rimsha", "Ahmed"],
#       3     "Age" : [21, 23, 24],
#       4     "Score": [75, 85, 65]
#       5 }
# ----> 7 students_df = pd.DataFrame(students_data)
#
# NameError: name 'pd' is not defined

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.0 MB 11.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.5/11.0 MB 11.7 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 11.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.8 MB 11.9 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/12.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------ --------- 9.7/12.8 MB 11.8 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
students_data = {
    'Name' : ["Adeen", "Rimsha", "Ahmed"],
    "Age" : [21, 23, 24],
    "Score": [75, 85, 65]
}

students_df = pd.DataFrame(students_data)

# %%
students_df.head(2)
# Out:
#      Name  Age  Score
# 0   Adeen   21     75
# 1  Rimsha   23     85

# %%
students_df[["Name", "Score"]]
# Out:
#      Name  Score
# 0   Adeen     75
# 1  Rimsha     85
# 2   Ahmed     65

# %%
students_df.iloc[1]
# Out:
# Name     Rimsha
# Age          23
# Score        85
# Name: 1, dtype: object

# %%
superstore_df[["Customer Name","Sales"]].head()
# Out:
#      Customer Name     Sales
# 0      Claire Gute  261.9600
# 1      Claire Gute  731.9400
# 2  Darrin Van Huff   14.6200
# 3   Sean O'Donnell  957.5775
# 4   Sean O'Donnell   22.3680

# %%
superstore_df[superstore_df["Discount"] == 0]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 5          6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 6          7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# ...

# %%
superstore_df[(superstore_df["Profit"] < 0)&(superstore_df["Discount"] == 0)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
students_df
# Out:
#      Name  Age  Score
# 0   Adeen   21     75
# 1  Rimsha   23     85
# 2   Ahmed   24     65

# %%
students_df["Remarks"] = (students_df["Score"] < 70).map({True: "Fail", False: "Pass"})

# %%
students_df
# Out:
#      Name  Age  Score Remarks
# 0   Adeen   21     75    Pass
# 1  Rimsha   23     85    Pass
# 2   Ahmed   24     65    Fail

# %%
students_data = {
    'Name' : ["Adeen", "Rimsha", "Ahmed"],
    "Age" : [21, 23, 24],
    "Score": [75, 85, 65]
}

students_df = pd.DataFrame(students_data)

students_df[["Name", "Score"]]
students_df.iloc[1]
superstore_df[["Customer Name","Sales"]].head()
superstore_df[superstore_df["Discount"] == 0]
superstore_df[(superstore_df["Profit"] < 0)&(superstore_df["Discount"] == 0)]
students_df["Remarks"] = (students_df["Score"] < 70).map({True: "Fail", False: "Pass"})
